# %%
#CTA

# %%
suppressPackageStartupMessages({
library(MASS, quietly = TRUE)
library(stringi, quietly = TRUE)
library(dplyr, quietly = TRUE)
library(tidyr, quietly = TRUE)
library(ggplot2, quietly = TRUE)
library(data.table, quietly = TRUE)
library(quanteda, quietly = TRUE)
library(xlsx, quietly = TRUE)
library(stringr, quietly = TRUE)
library(xtable, quietly = TRUE)
    library(mfx, quietly = TRUE)
    library(forcats, quietly = TRUE)
    library(ggalt)
    library(stm)
    })
# Out:
# Warning message:
# "Paket 'stringi' wurde unter R Version 4.2.2 erstellt"
# Warning message:
# "Paket 'dplyr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'tidyr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'ggplot2' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'data.table' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'quanteda' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'xlsx' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'stringr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'xtable' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'mfx' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'sandwich' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'lmtest' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'zoo' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'betareg' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'forcats' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'ggalt' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'stm' wurde unter R Version 4.2.3 erstellt"

# %%
path_data <- ""
df <- read.csv(paste(path_data,'tdm1011_metadata.csv',sep=''))

# Assign values to 'text', 'outcome', and 'metadata'
text <- df$strategy.description
outcome <- df$primed.for.intuition
metadata <- df[c('education','female','contribution','normalized.contribution')]

# %%
df$nsentence <- ifelse(is.na(text)==F,nsentence(text),NA)
df$nwords <- ifelse(is.na(text)==F,str_count(text, "\\w+"),NA)
# Out:
# Warning message in nsentence.character(text):
# "nsentence() does not correctly count sentences in all lower-cased text"

# %%
mean(df$nsentence)
median(df$nsentence)
sd(df$nsentence)
# Out:
# [1] 1.004032
# [1] 1
# [1] 0.06350006

# %%
mean(df$nwords)
median(df$nwords)
sd(df$nwords)
# Out:
# [1] 20.78629
# [1] 18
# [1] 12.5559

# %%
nrow(df)
# Out:
# [1] 248

# %%
library(udpipe)
library(BTM)
library("quanteda")
library("spacyr")
# Out:
# Warning message:
# "Paket 'udpipe' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'BTM' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'spacyr' wurde unter R Version 4.2.3 erstellt"

# %%
tdm_lemma <- read.csv(paste(path_data,'tdm_lemmatized.csv',sep=''))

# %%
toks_q <- tokens(tdm_lemma$text,
  remove_punct = TRUE, remove_numbers = TRUE
) %>%
  tokens_tolower()

# %%
as.data.frame.tokens <- function(x) {
  data.frame(
    doc_id = rep(names(x), lengths(x)),
#       doc_id = rep(lengths(x)),
    tokens = unlist(x, use.names = FALSE)
  )
}

# %%
set.seed(42)
model2 <- BTM(as.data.frame.tokens(toks_q), k = 4, beta = 0.01, iter = 100, trace = 10)
# Out:
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 1/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 11/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 21/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 31/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 41/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 51/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 61/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 71/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 81/100
# 2024-07-28 10:19:40 Start Gibbs sampling iteration 91/100

# %%
# Convert to dataframe
df_topic_probabilities <- data.frame(predict(model2, newdata = as.data.frame.tokens(toks_q)))

# Rename the columns
colnames(df_topic_probabilities) <- paste0("topic_", 1:ncol(df_topic_probabilities))

df_topic_probabilities$doc <- rownames(df_topic_probabilities)

# If you want 'doc' to be the first column
df_topic_probabilities <- df_topic_probabilities[, c(ncol(df_topic_probabilities), 1:(ncol(df_topic_probabilities)-1))]
df_topic_probabilities$doc <- as.numeric(gsub("text", "", df_topic_probabilities$doc))
df_topic_probabilities <- df_topic_probabilities[order(df_topic_probabilities$doc), ]
rownames(df_topic_probabilities) <- NULL

# %%
write.csv(df_topic_probabilities, 
          paste(path_data,"btm_tdm_topic_probabilities.csv",sep=''),
          row.names = FALSE)

# %%
# Get top words for each topic
top_words <- terms(model2, top_n = 5)

# Initialize an empty dataframe
df_top_words <- data.frame(matrix(ncol = length(top_words), nrow = 1))

# Fill the dataframe
for (i in 1:length(top_words)) {
  df_top_words[,i] <- paste(top_words[[i]]$token, collapse = ", ")
}

# Rename the columns
colnames(df_top_words) <- paste0("topic_", 1:ncol(df_top_words))

# %%
write.csv(df_top_words, 
          paste(path_data,"btm_tdm_top_words.csv",sep=''), 
          row.names = FALSE)

# %%
df_top_words
# Out:
#   topic_1                              topic_2
# 1 contribute, cent, good, group, money good, group, believe, like, decision
#   topic_3                               topic_4
# 1 people, cent, contribute, group, want contribute, people, feel, want, believe

# %%
#stm

temp<-textProcessor(documents=tdm_lemma$text,metadata=tdm_lemma,stem = FALSE)
out <- prepDocuments(temp$documents, temp$vocab, temp$meta)
# Out:
# Building corpus...
# Converting to Lower Case...
# Removing punctuation...
# Removing stopwords...
# Removing numbers...
# Creating Output...
# Removing 249 of 432 terms (249 of 1508 tokens) due to frequency
# Removing 4 Documents with No Words
# Your corpus now has 244 documents, 183 terms and 1259 tokens.

# %%
# help(textProcessor)

# %%
set.seed(42)
mod.out <- stm(out$documents, out$vocab, 4,seed=42,
prevalence=~treatment, data=out$meta,max.em.its = 1000)
# Out:
# Beginning Spectral Initialization
# 	 Calculating the gram matrix...
# 	 Finding anchor words...
#  	....
# 	 Recovering initialization...
#  	.
# Initialization complete.
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 1 (approx. per word bound = -4.961)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# ...
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 268 (approx. per word bound = -4.578, relative change = 2.725e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 269 (approx. per word bound = -4.578, relative change = 2.688e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 270 (approx. per word bound = -4.578, relative change = 2.664e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 271 (approx. per word bound = -4.577, relative change = 2.637e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 272 (approx. per word bound = -4.577, relative change = 2.623e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 273 (approx. per word bound = -4.577, relative change = 2.610e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 274 (approx. per word bound = -4.577, relative change = 2.621e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 275 (approx. per word bound = -4.577, relative change = 2.632e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 276 (approx. per word bound = -4.577, relative change = 2.658e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 277 (approx. per word bound = -4.577, relative change = 2.699e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 278 (approx. per word bound = -4.577, relative change = 2.753e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 279 (approx. per word bound = -4.576, relative change = 2.831e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 280 (approx. per word bound = -4.576, relative change = 2.931e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 281 (approx. per word bound = -4.576, relative change = 3.055e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 282 (approx. per word bound = -4.576, relative change = 3.220e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 283 (approx. per word bound = -4.576, relative change = 3.421e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 284 (approx. per word bound = -4.576, relative change = 3.682e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 285 (approx. per word bound = -4.575, relative change = 3.992e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 286 (approx. per word bound = -4.575, relative change = 4.362e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 287 (approx. per word bound = -4.575, relative change = 4.770e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 288 (approx. per word bound = -4.575, relative change = 5.173e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 289 (approx. per word bound = -4.575, relative change = 5.508e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 290 (approx. per word bound = -4.574, relative change = 5.704e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 291 (approx. per word bound = -4.574, relative change = 5.724e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 292 (approx. per word bound = -4.574, relative change = 5.540e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 293 (approx. per word bound = -4.574, relative change = 5.203e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 294 (approx. per word bound = -4.573, relative change = 4.778e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 295 (approx. per word bound = -4.573, relative change = 4.357e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 296 (approx. per word bound = -4.573, relative change = 4.026e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 297 (approx. per word bound = -4.573, relative change = 3.807e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 298 (approx. per word bound = -4.573, relative change = 3.761e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 299 (approx. per word bound = -4.572, relative change = 3.912e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 300 (approx. per word bound = -4.572, relative change = 4.234e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 301 (approx. per word bound = -4.572, relative change = 4.696e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 302 (approx. per word bound = -4.572, relative change = 5.208e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 303 (approx. per word bound = -4.572, relative change = 5.626e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 304 (approx. per word bound = -4.571, relative change = 5.824e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 305 (approx. per word bound = -4.571, relative change = 5.724e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 306 (approx. per word bound = -4.571, relative change = 5.362e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 307 (approx. per word bound = -4.571, relative change = 4.872e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 308 (approx. per word bound = -4.570, relative change = 4.368e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 309 (approx. per word bound = -4.570, relative change = 3.946e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 310 (approx. per word bound = -4.570, relative change = 3.611e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 311 (approx. per word bound = -4.570, relative change = 3.361e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 312 (approx. per word bound = -4.570, relative change = 3.151e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 313 (approx. per word bound = -4.570, relative change = 2.933e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 314 (approx. per word bound = -4.569, relative change = 2.686e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 315 (approx. per word bound = -4.569, relative change = 2.395e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 316 (approx. per word bound = -4.569, relative change = 2.068e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 317 (approx. per word bound = -4.569, relative change = 1.774e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 318 (approx. per word bound = -4.569, relative change = 1.502e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 319 (approx. per word bound = -4.569, relative change = 1.275e-05)
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 320 (approx. per word bound = -4.569, relative change = 1.087e-05)
# Topic 1: want, choose, feel, give, fair
#  Topic 2: group, think, benefit, way, decide
#  Topic 3: people, good, like, hope, know
#  Topic 4: contribute, money, cent, believe, figure
# ..........................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Model Converged

# %%
summary(mod.out)
# Out:
# A topic model with 4 topics, 244 documents and a 183 word dictionary.
# Topic 1 Top Words:
#  	 Highest Prob: want, choose, feel, give, fair, right, greedy
#  	 FREX: want, greedy, away, answer, help, player, sense
#  	 Lift: want, answer, away, communicate, daily, deal, enjoy
#  	 Score: want, experience, feel, greedy, fair, choose, right
# Topic 2 Top Words:
#  	 Highest Prob: group, think, benefit, way, decide, thing, little
#  	 FREX: group, think, benefit, way, decide, bit, lose
#  	 Lift: leave, take, base, benefit, group, think, way
#  	 Score: group, benefit, rely, decide, think, way, bit
# Topic 3 Top Words:
#  	 Highest Prob: people, good, like, hope, know, risk, try
#  	 FREX: like, life, gain, gamble, sure, good, involve
#  	 Lift: gain, gamble, sure, averse, certain, contributing, find
#  	 Score: people, good, instinct, like, know, hope, life
# Topic 4 Top Words:
#  	 Highest Prob: contribute, money, cent, believe, figure, bonus, chance
#  	 FREX: contribute, cent, figure, bonus, chance, half, get
#  	 Lift: chance, half, allow, bible, cent, christian, consider
#  	 Score: contribute, cent, money, christian, figure, receive, half

# %%
stm_topic_proportions <- as.data.frame(mod.out$theta)
# Get the number of topics
num_topics <- ncol(stm_topic_proportions)

# Create the new column names
new_colnames <- paste0("topic_", 1:num_topics)

# Assign the new column names to the dataframe
colnames(stm_topic_proportions) <- new_colnames

# %%
stm_topic_proportions$treatment <- out$meta$treatment

# %%
write.csv(stm_topic_proportions, 
          paste(path_data,"stm_tdm_topic_probabilities.csv",sep=''),
          row.names = FALSE)

# %%
# Get the top 5 words for each topic
top_words <- labelTopics(mod.out, n=5)

# Convert the matrix to a dataframe
stm_top_words <- as.data.frame(t(top_words$prob))

# Convert the top words for each topic to a single string, separated by a comma
stm_top_words <- apply(stm_top_words, 2, paste, collapse = ", ")

# Convert the matrix back to a dataframe
stm_top_words <- as.data.frame(t(stm_top_words))

# Assign the new column names to the dataframe
colnames(stm_top_words) <- new_colnames

# %%
stm_top_words
# Out:
#   topic_1                        topic_2
# 1 want, choose, feel, give, fair group, think, benefit, way, decide
#   topic_3                        topic_4
# 1 people, good, like, hope, know contribute, money, cent, believe, figure

# %%
write.csv(stm_top_words, 
          paste(path_data,"stm_tdm_top_words.csv",sep=''), 
          row.names = FALSE)

# %%
# Make plots

# %%
# load X_all
feature_imp <- read.csv(paste(path_data,"cta_data/tdm_intuition_shap_bert_170824.csv",sep='')
                          ,header = TRUE, sep = ",")


# compute mean and t-val for each word

words_shap <- data.frame(word=colnames(feature_imp))
words_shap$mean <- 0
words_shap$se <- 0
words_shap$t_val <- 0
words_shap$p_val <- 0


for (i in c(1:nrow(words_shap))){
    word_name <- words_shap$word[i]
    shap_col <- feature_imp[,word_name]
#     shap_col <- shap_col[which(shap_col!=0)]
    words_shap$mean[i] <- mean(shap_col)
#     words_shap$median[i] <- median(shap_col)
    words_shap$se[i] <- sd(shap_col)/sqrt(length(shap_col))
    words_shap$t_val[i] <- abs(words_shap$mean[i]/words_shap$se[i])
#     words_shap$t_val[i] <- abs(words_shap$mean[i]/(words_shap$sd[i]))
    words_shap$p_val[i] <- t.test(feature_imp[,word_name])$p.val
}
words_shap$mean_abs <- abs(words_shap$mean)
words_shap <- words_shap[order(-words_shap$mean_abs),]

n_words <- 5
# word_shap_tmp <- words_shap[which(words_shap$mean>0&words_shap$t_val>1.96),]
word_shap_tmp <- words_shap[which(words_shap$mean>0&words_shap$p_val<0.1),]
words_tmp <- word_shap_tmp[1:n_words,'word']
# words_tmp_corr <- word_shap_tmp[1:n_words,'word_corr']

# word_shap_tmp <- words_shap[which(words_shap$mean<0&words_shap$t_val>1.96),]
word_shap_tmp <- words_shap[which(words_shap$mean<0&words_shap$p_val<0.1),]
words_tmp <- c(words_tmp,word_shap_tmp[1:n_words,'word'])
# words_tmp_corr <-  c(words_tmp_corr,word_shap_tmp[1:n_words,'word_corr'])

shap_words_tmp <- feature_imp[,words_tmp]


# reshape as long datafile

index <- 1
for (i in colnames(shap_words_tmp)){
    n_obs <- nrow(shap_words_tmp)
    if(index==1){
        shap_words_tmp_reshape <- data.frame(shap=shap_words_tmp[,index],word=colnames(shap_words_tmp)[index])
    }else{
        tmp_reshape <- data.frame(shap=shap_words_tmp[,index],word=colnames(shap_words_tmp)[index])
        shap_words_tmp_reshape <- rbind(shap_words_tmp_reshape,tmp_reshape)
    }
    index <- index+1
}

# shap_words_tmp_reshape <- shap_words_tmp_reshape[which(shap_words_tmp_reshape$shap!=0),]
shap_words_tmp_reshape$word <- fct_rev(factor(shap_words_tmp_reshape$word , levels=colnames(shap_words_tmp)))

min.mean.sd.max <- function(x) {
  r <- c(t.test(x, conf.level = 0.90)$"conf.int"[1], t.test(x, conf.level = 0.90)$"conf.int"[1], 
         mean(x), t.test(x, conf.level = 0.90)$"conf.int"[2], 
         t.test(x, conf.level = 0.90)$"conf.int"[2])
  names(r) <- c("ymin", "lower", "middle", "upper", "ymax")
  r
}

ggplot(shap_words_tmp_reshape, aes(x = shap, y = word)) + 
  geom_vline(xintercept =0) + 
  theme_light() + 
  xlab("SHAP Value") +
  theme(axis.title.x = element_text(size = 20),
        axis.text.x = element_text(size = 12),
        axis.title.y = element_text(size =0),
        axis.text.y = element_text(size =20)) +
  stat_summary(fun.data = min.mean.sd.max, geom = "errorbar", size=0.5) +
  stat_summary(
    geom = "point",
    fun = "mean",
    col = "black",
    size = 3,
    shape = 21,
    fill = "black"
  )
# Out:
# Warning message:
# "Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead."
# plot without title
