# %%
#CTA

# %%
suppressPackageStartupMessages({
library(MASS, quietly = TRUE)
library(stringi, quietly = TRUE)
library(wordcloud, quietly = TRUE)
library(dplyr, quietly = TRUE)
library(tidyr, quietly = TRUE)
library(ggplot2, quietly = TRUE)
library(data.table, quietly = TRUE)
library(stargazer, quietly = TRUE)
library(quanteda, quietly = TRUE)
library(xlsx, quietly = TRUE)
library(stringr, quietly = TRUE)
library(xtable, quietly = TRUE)
    library(mfx, quietly = TRUE)
    library(forcats, quietly = TRUE)
    library(ggalt)
    library(stm)
    })
# Out:
# Warning message:
# "Paket 'stringi' wurde unter R Version 4.2.2 erstellt"
# Warning message:
# "Paket 'wordcloud' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'dplyr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'tidyr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'ggplot2' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'data.table' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'quanteda' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'xlsx' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'stringr' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'xtable' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'mfx' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'sandwich' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'lmtest' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'zoo' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'betareg' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'forcats' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'ggalt' wurde unter R Version 4.2.1 erstellt"
# Warning message:
# "Paket 'stm' wurde unter R Version 4.2.3 erstellt"

# %%
library(udpipe)
library(BTM)
library("quanteda")
library("spacyr")
# Out:
# Warning message:
# "Paket 'udpipe' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'BTM' wurde unter R Version 4.2.3 erstellt"
# Warning message:
# "Paket 'spacyr' wurde unter R Version 4.2.3 erstellt"

# %%
path_data <- ""

# %%
gadarian_data <- read.csv(paste(path_data,'cta_data/gadarian_lemmatized.csv',sep=''))

# %%
toks_q <- tokens(gadarian_data$text_lemma,
  remove_punct = TRUE, remove_numbers = TRUE
) %>%
  tokens_tolower()

# %%
as.data.frame.tokens <- function(x) {
  data.frame(
    doc_id = rep(names(x), lengths(x)),
#       doc_id = rep(lengths(x)),
    tokens = unlist(x, use.names = FALSE)
  )
}

# %%
set.seed(42)
model2 <- BTM(as.data.frame.tokens(toks_q), k = 4, beta = 0.01, iter = 100, trace = 10)
# Out:
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 1/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 11/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 21/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 31/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 41/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 51/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 61/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 71/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 81/100
# 2024-07-29 11:27:20 Start Gibbs sampling iteration 91/100

# %%
# Convert to dataframe
df_topic_probabilities <- data.frame(predict(model2, newdata = as.data.frame.tokens(toks_q)))

# Rename the columns
colnames(df_topic_probabilities) <- paste0("topic_", 1:ncol(df_topic_probabilities))

df_topic_probabilities$doc <- rownames(df_topic_probabilities)

# If you want 'doc' to be the first column
df_topic_probabilities <- df_topic_probabilities[, c(ncol(df_topic_probabilities), 1:(ncol(df_topic_probabilities)-1))]
df_topic_probabilities$doc <- as.numeric(gsub("text", "", df_topic_probabilities$doc))
df_topic_probabilities <- df_topic_probabilities[order(df_topic_probabilities$doc), ]
rownames(df_topic_probabilities) <- NULL

# %%
write.csv(df_topic_probabilities, 
          paste(path_data,"btm_gadarian_topic_probabilities.csv",sep=''),
          row.names = FALSE)

# %%
# Get top words for each topic
top_words <- terms(model2, top_n = 5)

# Initialize an empty dataframe
df_top_words <- data.frame(matrix(ncol = length(top_words), nrow = 1))

# Fill the dataframe
for (i in 1:length(top_words)) {
  df_top_words[,i] <- paste(top_words[[i]]$token, collapse = ", ")
}

# Rename the columns
colnames(df_top_words) <- paste0("topic_", 1:ncol(df_top_words))

# %%
write.csv(df_top_words, 
          paste(path_data,"btm_gadarian_top_words.csv",sep=''), 
          row.names = FALSE)

# %%
#stm

temp<-textProcessor(documents=gadarian_data$text_lemma,metadata=gadarian_data,stem = FALSE)
out <- prepDocuments(temp$documents, temp$vocab, temp$meta)
# Out:
# Building corpus...
# Converting to Lower Case...
# Removing punctuation...
# Removing stopwords...
# Removing numbers...
# Creating Output...
# Removing 662 of 1068 terms (662 of 3404 tokens) due to frequency
# Removing 4 Documents with No Words
# Your corpus now has 345 documents, 406 terms and 2742 tokens.

# %%
set.seed(42)
mod.out <- stm(out$documents, out$vocab, 4,seed=42,
prevalence=~outcome, data=out$meta,max.em.its = 1000)
# Out:
# Beginning Spectral Initialization
# 	 Calculating the gram matrix...
# 	 Finding anchor words...
#  	....
# 	 Recovering initialization...
#  	....
# Initialization complete.
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 1 (approx. per word bound = -5.594)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 2 (approx. per word bound = -5.451, relative change = 2.554e-02)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 3 (approx. per word bound = -5.391, relative change = 1.097e-02)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 4 (approx. per word bound = -5.363, relative change = 5.190e-03)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 5 (approx. per word bound = -5.348, relative change = 2.779e-03)
# Topic 1: people, pay, english, citizen, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 6 (approx. per word bound = -5.339, relative change = 1.645e-03)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 7 (approx. per word bound = -5.334, relative change = 1.053e-03)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 8 (approx. per word bound = -5.330, relative change = 7.184e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 9 (approx. per word bound = -5.327, relative change = 5.151e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 10 (approx. per word bound = -5.325, relative change = 3.845e-04)
# Topic 1: people, pay, english, citizen, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 11 (approx. per word bound = -5.323, relative change = 2.965e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 12 (approx. per word bound = -5.322, relative change = 2.348e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 13 (approx. per word bound = -5.321, relative change = 1.904e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 14 (approx. per word bound = -5.320, relative change = 1.579e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 15 (approx. per word bound = -5.320, relative change = 1.333e-04)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 16 (approx. per word bound = -5.319, relative change = 1.146e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 17 (approx. per word bound = -5.318, relative change = 9.977e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 18 (approx. per word bound = -5.318, relative change = 8.757e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 19 (approx. per word bound = -5.318, relative change = 7.709e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 20 (approx. per word bound = -5.317, relative change = 6.784e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 21 (approx. per word bound = -5.317, relative change = 6.001e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 22 (approx. per word bound = -5.317, relative change = 5.301e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 23 (approx. per word bound = -5.316, relative change = 4.723e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 24 (approx. per word bound = -5.316, relative change = 4.232e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 25 (approx. per word bound = -5.316, relative change = 3.810e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 26 (approx. per word bound = -5.316, relative change = 3.451e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 27 (approx. per word bound = -5.316, relative change = 3.150e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 28 (approx. per word bound = -5.315, relative change = 2.899e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 29 (approx. per word bound = -5.315, relative change = 2.700e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 30 (approx. per word bound = -5.315, relative change = 2.555e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 31 (approx. per word bound = -5.315, relative change = 2.453e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 32 (approx. per word bound = -5.315, relative change = 2.395e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 33 (approx. per word bound = -5.315, relative change = 2.381e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 34 (approx. per word bound = -5.315, relative change = 2.411e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 35 (approx. per word bound = -5.315, relative change = 2.485e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 36 (approx. per word bound = -5.314, relative change = 2.603e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 37 (approx. per word bound = -5.314, relative change = 2.764e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 38 (approx. per word bound = -5.314, relative change = 2.971e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 39 (approx. per word bound = -5.314, relative change = 3.206e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 40 (approx. per word bound = -5.314, relative change = 3.457e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 41 (approx. per word bound = -5.314, relative change = 3.687e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 42 (approx. per word bound = -5.313, relative change = 3.852e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 43 (approx. per word bound = -5.313, relative change = 3.910e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 44 (approx. per word bound = -5.313, relative change = 3.838e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 45 (approx. per word bound = -5.313, relative change = 3.663e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 46 (approx. per word bound = -5.313, relative change = 3.432e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 47 (approx. per word bound = -5.312, relative change = 3.201e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 48 (approx. per word bound = -5.312, relative change = 3.001e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 49 (approx. per word bound = -5.312, relative change = 2.839e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 50 (approx. per word bound = -5.312, relative change = 2.692e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 51 (approx. per word bound = -5.312, relative change = 2.550e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 52 (approx. per word bound = -5.312, relative change = 2.411e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 53 (approx. per word bound = -5.312, relative change = 2.291e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 54 (approx. per word bound = -5.311, relative change = 2.201e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 55 (approx. per word bound = -5.311, relative change = 2.161e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 56 (approx. per word bound = -5.311, relative change = 2.169e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 57 (approx. per word bound = -5.311, relative change = 2.223e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 58 (approx. per word bound = -5.311, relative change = 2.310e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 59 (approx. per word bound = -5.311, relative change = 2.424e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 60 (approx. per word bound = -5.311, relative change = 2.552e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 61 (approx. per word bound = -5.311, relative change = 2.681e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 62 (approx. per word bound = -5.310, relative change = 2.804e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 63 (approx. per word bound = -5.310, relative change = 2.901e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 64 (approx. per word bound = -5.310, relative change = 2.970e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 65 (approx. per word bound = -5.310, relative change = 3.003e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 66 (approx. per word bound = -5.310, relative change = 3.008e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 67 (approx. per word bound = -5.310, relative change = 2.981e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 68 (approx. per word bound = -5.309, relative change = 2.938e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 69 (approx. per word bound = -5.309, relative change = 2.884e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 70 (approx. per word bound = -5.309, relative change = 2.833e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 71 (approx. per word bound = -5.309, relative change = 2.780e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 72 (approx. per word bound = -5.309, relative change = 2.729e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 73 (approx. per word bound = -5.309, relative change = 2.685e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 74 (approx. per word bound = -5.309, relative change = 2.627e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 75 (approx. per word bound = -5.308, relative change = 2.565e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 76 (approx. per word bound = -5.308, relative change = 2.491e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 77 (approx. per word bound = -5.308, relative change = 2.418e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 78 (approx. per word bound = -5.308, relative change = 2.355e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 79 (approx. per word bound = -5.308, relative change = 2.308e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 80 (approx. per word bound = -5.308, relative change = 2.292e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 81 (approx. per word bound = -5.308, relative change = 2.306e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 82 (approx. per word bound = -5.308, relative change = 2.332e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 83 (approx. per word bound = -5.307, relative change = 2.359e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 84 (approx. per word bound = -5.307, relative change = 2.363e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 85 (approx. per word bound = -5.307, relative change = 2.337e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 86 (approx. per word bound = -5.307, relative change = 2.291e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 87 (approx. per word bound = -5.307, relative change = 2.236e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 88 (approx. per word bound = -5.307, relative change = 2.206e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 89 (approx. per word bound = -5.307, relative change = 2.217e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 90 (approx. per word bound = -5.307, relative change = 2.286e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 91 (approx. per word bound = -5.306, relative change = 2.418e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 92 (approx. per word bound = -5.306, relative change = 2.591e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 93 (approx. per word bound = -5.306, relative change = 2.770e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 94 (approx. per word bound = -5.306, relative change = 2.896e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 95 (approx. per word bound = -5.306, relative change = 2.915e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 96 (approx. per word bound = -5.306, relative change = 2.811e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 97 (approx. per word bound = -5.306, relative change = 2.609e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 98 (approx. per word bound = -5.305, relative change = 2.378e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 99 (approx. per word bound = -5.305, relative change = 2.177e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 100 (approx. per word bound = -5.305, relative change = 2.048e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 101 (approx. per word bound = -5.305, relative change = 2.020e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 102 (approx. per word bound = -5.305, relative change = 2.102e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 103 (approx. per word bound = -5.305, relative change = 2.313e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 104 (approx. per word bound = -5.305, relative change = 2.656e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 105 (approx. per word bound = -5.305, relative change = 3.148e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 106 (approx. per word bound = -5.304, relative change = 3.760e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 107 (approx. per word bound = -5.304, relative change = 4.412e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 108 (approx. per word bound = -5.304, relative change = 4.969e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 109 (approx. per word bound = -5.304, relative change = 5.315e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 110 (approx. per word bound = -5.303, relative change = 5.462e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 111 (approx. per word bound = -5.303, relative change = 5.529e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 112 (approx. per word bound = -5.303, relative change = 5.554e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 113 (approx. per word bound = -5.302, relative change = 5.419e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 114 (approx. per word bound = -5.302, relative change = 4.926e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 115 (approx. per word bound = -5.302, relative change = 4.114e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 116 (approx. per word bound = -5.302, relative change = 3.264e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 117 (approx. per word bound = -5.302, relative change = 2.614e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 118 (approx. per word bound = -5.302, relative change = 2.224e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 119 (approx. per word bound = -5.301, relative change = 2.053e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 120 (approx. per word bound = -5.301, relative change = 2.029e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 121 (approx. per word bound = -5.301, relative change = 2.105e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 122 (approx. per word bound = -5.301, relative change = 2.269e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 123 (approx. per word bound = -5.301, relative change = 2.466e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 124 (approx. per word bound = -5.301, relative change = 2.689e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 125 (approx. per word bound = -5.301, relative change = 2.897e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 126 (approx. per word bound = -5.300, relative change = 3.029e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 127 (approx. per word bound = -5.300, relative change = 3.070e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 128 (approx. per word bound = -5.300, relative change = 3.036e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 129 (approx. per word bound = -5.300, relative change = 2.987e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 130 (approx. per word bound = -5.300, relative change = 3.003e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 131 (approx. per word bound = -5.300, relative change = 3.112e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 132 (approx. per word bound = -5.300, relative change = 3.361e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 133 (approx. per word bound = -5.299, relative change = 3.742e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 134 (approx. per word bound = -5.299, relative change = 4.241e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 135 (approx. per word bound = -5.299, relative change = 4.803e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 136 (approx. per word bound = -5.299, relative change = 5.344e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 137 (approx. per word bound = -5.298, relative change = 5.766e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 138 (approx. per word bound = -5.298, relative change = 6.013e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 139 (approx. per word bound = -5.298, relative change = 6.107e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 140 (approx. per word bound = -5.297, relative change = 6.144e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 141 (approx. per word bound = -5.297, relative change = 6.243e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 142 (approx. per word bound = -5.297, relative change = 6.541e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 143 (approx. per word bound = -5.296, relative change = 7.232e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 144 (approx. per word bound = -5.296, relative change = 8.582e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 145 (approx. per word bound = -5.295, relative change = 1.068e-04)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 146 (approx. per word bound = -5.295, relative change = 1.237e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 147 (approx. per word bound = -5.294, relative change = 1.179e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 148 (approx. per word bound = -5.293, relative change = 1.003e-04)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 149 (approx. per word bound = -5.293, relative change = 8.095e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 150 (approx. per word bound = -5.293, relative change = 6.239e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 151 (approx. per word bound = -5.292, relative change = 5.044e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 152 (approx. per word bound = -5.292, relative change = 4.445e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 153 (approx. per word bound = -5.292, relative change = 4.215e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 154 (approx. per word bound = -5.292, relative change = 4.185e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 155 (approx. per word bound = -5.291, relative change = 4.201e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 156 (approx. per word bound = -5.291, relative change = 4.154e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 157 (approx. per word bound = -5.291, relative change = 4.009e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 158 (approx. per word bound = -5.291, relative change = 3.826e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 159 (approx. per word bound = -5.291, relative change = 3.631e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 160 (approx. per word bound = -5.290, relative change = 3.459e-05)
# Topic 1: people, pay, citizen, english, language
#  Topic 2: immigrant, immigration, work, security, care
#  Topic 3: illegal, country, border, legal, worry
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 161 (approx. per word bound = -5.290, relative change = 3.316e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 162 (approx. per word bound = -5.290, relative change = 3.207e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# ...
# Completing Iteration 472 (approx. per word bound = -5.221, relative change = 1.708e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 473 (approx. per word bound = -5.221, relative change = 1.415e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 474 (approx. per word bound = -5.220, relative change = 1.218e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 475 (approx. per word bound = -5.220, relative change = 1.121e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 476 (approx. per word bound = -5.220, relative change = 1.050e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 477 (approx. per word bound = -5.220, relative change = 1.018e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 478 (approx. per word bound = -5.220, relative change = 1.040e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 479 (approx. per word bound = -5.220, relative change = 1.022e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 480 (approx. per word bound = -5.220, relative change = 1.032e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 481 (approx. per word bound = -5.220, relative change = 1.063e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 482 (approx. per word bound = -5.220, relative change = 1.070e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 483 (approx. per word bound = -5.220, relative change = 1.143e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 484 (approx. per word bound = -5.220, relative change = 1.207e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 485 (approx. per word bound = -5.220, relative change = 1.257e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 486 (approx. per word bound = -5.220, relative change = 1.300e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 487 (approx. per word bound = -5.220, relative change = 1.274e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 488 (approx. per word bound = -5.220, relative change = 1.196e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 489 (approx. per word bound = -5.220, relative change = 1.135e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 490 (approx. per word bound = -5.219, relative change = 1.101e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 491 (approx. per word bound = -5.219, relative change = 1.131e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 492 (approx. per word bound = -5.219, relative change = 1.229e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 493 (approx. per word bound = -5.219, relative change = 1.378e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 494 (approx. per word bound = -5.219, relative change = 1.561e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 495 (approx. per word bound = -5.219, relative change = 1.778e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 496 (approx. per word bound = -5.219, relative change = 2.036e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 497 (approx. per word bound = -5.219, relative change = 2.337e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 498 (approx. per word bound = -5.219, relative change = 2.698e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 499 (approx. per word bound = -5.219, relative change = 3.100e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 500 (approx. per word bound = -5.218, relative change = 3.408e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 501 (approx. per word bound = -5.218, relative change = 3.529e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 502 (approx. per word bound = -5.218, relative change = 3.420e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 503 (approx. per word bound = -5.218, relative change = 3.078e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 504 (approx. per word bound = -5.218, relative change = 2.653e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 505 (approx. per word bound = -5.218, relative change = 2.228e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 506 (approx. per word bound = -5.218, relative change = 1.864e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 507 (approx. per word bound = -5.217, relative change = 1.591e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 508 (approx. per word bound = -5.217, relative change = 1.407e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 509 (approx. per word bound = -5.217, relative change = 1.303e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 510 (approx. per word bound = -5.217, relative change = 1.284e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 511 (approx. per word bound = -5.217, relative change = 1.338e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 512 (approx. per word bound = -5.217, relative change = 1.419e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 513 (approx. per word bound = -5.217, relative change = 1.633e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 514 (approx. per word bound = -5.217, relative change = 1.948e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 515 (approx. per word bound = -5.217, relative change = 2.353e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 516 (approx. per word bound = -5.217, relative change = 2.858e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 517 (approx. per word bound = -5.216, relative change = 3.201e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 518 (approx. per word bound = -5.216, relative change = 3.145e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 519 (approx. per word bound = -5.216, relative change = 2.708e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 520 (approx. per word bound = -5.216, relative change = 2.184e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 521 (approx. per word bound = -5.216, relative change = 1.772e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 522 (approx. per word bound = -5.216, relative change = 1.493e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 523 (approx. per word bound = -5.216, relative change = 1.300e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 524 (approx. per word bound = -5.216, relative change = 1.163e-05)
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Completing Iteration 525 (approx. per word bound = -5.216, relative change = 1.052e-05)
# Topic 1: people, country, pay, citizen, english
#  Topic 2: immigrant, immigration, border, work, security
#  Topic 3: illegal, legal, worry, welfare, crime
#  Topic 4: job, come, think, need, americans
# ...................................................................................................................
# Completed E-Step (0 seconds).
# Completed M-Step.
# Model Converged

# %%
stm_topic_proportions <- as.data.frame(mod.out$theta)
# Get the number of topics
num_topics <- ncol(stm_topic_proportions)

# Create the new column names
new_colnames <- paste0("topic_", 1:num_topics)

# Assign the new column names to the dataframe
colnames(stm_topic_proportions) <- new_colnames

# %%
stm_topic_proportions$outcome <- out$meta$outcome

# %%
stm_topic_proportions$fear_ra1 <- out$meta$fear_ra1
stm_topic_proportions$fear_ra2 <- out$meta$fear_ra2

# %%
write.csv(stm_topic_proportions, 
          paste(path_data,"stm_gadarian_topic_probabilities.csv",sep=''),
          row.names = FALSE)

# %%
# Get the top 5 words for each topic
top_words <- labelTopics(mod.out, n=5)

# Convert the matrix to a dataframe
stm_top_words <- as.data.frame(t(top_words$prob))

# Convert the top words for each topic to a single string, separated by a comma
stm_top_words <- apply(stm_top_words, 2, paste, collapse = ", ")

# Convert the matrix back to a dataframe
stm_top_words <- as.data.frame(t(stm_top_words))

# Assign the new column names to the dataframe
colnames(stm_top_words) <- new_colnames

# %%
stm_top_words
# Out:
#   topic_1
# 1 people, country, pay, citizen, english
#   topic_2
# 1 immigrant, immigration, border, work, security
#   topic_3                               topic_4
# 1 illegal, legal, worry, welfare, crime job, come, think, need, americans

# %%
write.csv(stm_top_words, 
          paste(path_data,"stm_gadarian_top_words.csv",sep=''), 
          row.names = FALSE)

# %%
word_shap_tmp
# Out:
#      word        mean         se          t_val    p_val        mean_abs
# 1023 illegal     -0.102010815 0.059398209 1.717406 0.0867947422 0.102010815
# 962  people      -0.101350520 0.039755500 2.549346 0.0112209180 0.101350520
# 189  think       -0.090574584 0.026524132 3.414799 0.0007136633 0.090574584
# 226  immigration -0.079252681 0.032147659 2.465271 0.0141730356 0.079252681
# 592  country     -0.075225095 0.021895246 3.435682 0.0006625350 0.075225095
# 876  border      -0.069919969 0.019582384 3.570554 0.0004063073 0.069919969
# 718  mexico      -0.069289864 0.024035817 2.882775 0.0041868456 0.069289864
# 142  legal       -0.063304086 0.020288560 3.120186 0.0019584074 0.063304086
# 923  mexican     -0.062822467 0.023834478 2.635781 0.0087701535 0.062822467
# 1064 fence       -0.038199860 0.017891297 2.135109 0.0334501093 0.038199860
# 660  usa         -0.021948497 0.010366910 2.117169 0.0349545598 0.021948497
# 616  law         -0.020777543 0.011015898 1.886141 0.0601083945 0.020777543
# 1012 opportunity -0.020106054 0.012158743 1.653629 0.0991045669 0.020106054
# 697  legally     -0.018851843 0.008519814 2.212706 0.0275665396 0.018851843
# 893  fine        -0.013013100 0.007339174 1.773101 0.0770865188 0.013013100
# 65   theirs      -0.004378750 0.002607202 1.679483 0.0939555142 0.004378750
# 902  good        -0.004144115 0.002421760 1.711200 0.0879353154 0.004144115
# 931  south       -0.003214321 0.001895683 1.695600 0.0908560746 0.003214321

# %%
# Make plots

# %%
# load X_all
feature_imp <- read.csv(paste(path_data,"cta_data/gadarian_treatment_shap_bert_180824.csv",sep='')
                          ,header = TRUE, sep = ",")

# compute mean and t-val for each word

words_shap <- data.frame(word=colnames(feature_imp))
words_shap$mean <- 0
words_shap$se <- 0
words_shap$t_val <- 0
words_shap$p_val <- 0


for (i in c(1:nrow(words_shap))){
    word_name <- words_shap$word[i]
    shap_col <- feature_imp[,word_name]
#     shap_col <- shap_col[which(shap_col!=0)]
    words_shap$mean[i] <- mean(shap_col)
#     words_shap$median[i] <- median(shap_col)
    words_shap$se[i] <- sd(shap_col)/sqrt(length(shap_col))
    words_shap$t_val[i] <- abs(words_shap$mean[i]/words_shap$se[i])
#     words_shap$t_val[i] <- abs(words_shap$mean[i]/(words_shap$sd[i]))
    words_shap$p_val[i] <- t.test(feature_imp[,word_name])$p.val
}
words_shap$mean_abs <- abs(words_shap$mean)
words_shap <- words_shap[order(-words_shap$mean_abs),]

n_words <- 5
# word_shap_tmp <- words_shap[which(words_shap$mean>0&words_shap$t_val>1.96),]
word_shap_tmp <- words_shap[which(words_shap$mean>0&words_shap$p_val<0.1),]
words_tmp <- word_shap_tmp[1:n_words,'word']
# words_tmp_corr <- word_shap_tmp[1:n_words,'word_corr']

# word_shap_tmp <- words_shap[which(words_shap$mean<0&words_shap$t_val>1.96),]
word_shap_tmp <- words_shap[which(words_shap$mean<0&words_shap$p_val<0.1),]
words_tmp <- c(words_tmp,word_shap_tmp[1:n_words,'word'])
# words_tmp_corr <-  c(words_tmp_corr,word_shap_tmp[1:n_words,'word_corr'])

shap_words_tmp <- feature_imp[,words_tmp]


# reshape as long datafile

index <- 1
for (i in colnames(shap_words_tmp)){
    n_obs <- nrow(shap_words_tmp)
    if(index==1){
        shap_words_tmp_reshape <- data.frame(shap=shap_words_tmp[,index],word=colnames(shap_words_tmp)[index])
    }else{
        tmp_reshape <- data.frame(shap=shap_words_tmp[,index],word=colnames(shap_words_tmp)[index])
        shap_words_tmp_reshape <- rbind(shap_words_tmp_reshape,tmp_reshape)
    }
    index <- index+1
}

# shap_words_tmp_reshape <- shap_words_tmp_reshape[which(shap_words_tmp_reshape$shap!=0),]
shap_words_tmp_reshape$word <- fct_rev(factor(shap_words_tmp_reshape$word , levels=colnames(shap_words_tmp)))

min.mean.sd.max <- function(x) {
  r <- c(t.test(x, conf.level = 0.90)$"conf.int"[1], t.test(x, conf.level = 0.90)$"conf.int"[1], 
         mean(x), t.test(x, conf.level = 0.90)$"conf.int"[2], 
         t.test(x, conf.level = 0.90)$"conf.int"[2])
  names(r) <- c("ymin", "lower", "middle", "upper", "ymax")
  r
}

ggplot(shap_words_tmp_reshape, aes(x = shap, y = word)) + 
  geom_vline(xintercept =0) + 
  theme_light() + 
  xlab("SHAP Value") +
  theme(axis.title.x = element_text(size = 20),
        axis.text.x = element_text(size = 12),
        axis.title.y = element_text(size =0),
        axis.text.y = element_text(size =20)) +
  stat_summary(fun.data = min.mean.sd.max, geom = "errorbar", size=0.5) +
  stat_summary(
    geom = "point",
    fun = "mean",
    col = "black",
    size = 3,
    shape = 21,
    fill = "black"
  )
# Out:
# plot without title
